# %%
# !pip install tensorflow

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# Load the Titanic dataset from the source URL
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

# Display the first few rows and info
print(data.head())
print(data.info())

# %%
# Handling Missing Values
# Fill missing Age with median
data['Age'].fillna(data['Age'].median(), inplace=True)

# Fill missing Embarked with mode (most common value)
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

# Drop Cabin (too many missing values, and not crucial for simple model)
data.drop('Cabin', axis=1, inplace=True)

# Drop irrelevant features
data.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)

# Encoding Categorical Data
# Encode Sex: male=0, female=1
label_encoder = LabelEncoder()
data['Sex'] = label_encoder.fit_transform(data['Sex'])

# One-hot encode Embarked
embarked_onehot = pd.get_dummies(data['Embarked'], prefix='Embarked')
data = pd.concat([data, embarked_onehot], axis=1)
data.drop('Embarked', axis=1, inplace=True)

# Separate features and target
X = data.drop('Survived', axis=1)
y = data['Survived']

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting Data into train and test (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Display shapes
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

# %%
# Define the Neural Network Architecture
model = Sequential()

# Input layer (implicit) + first hidden layer with ReLU
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))

# Second hidden layer with ReLU
model.add(Dense(units=32, activation='relu'))

# Output layer with sigmoid for binary classification
model.add(Dense(units=1, activation='sigmoid'))

# Compile the Model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,753 (10.75 KB)
#  Trainable params: 2,753 (10.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the Model
history = model.fit(X_train, y_train,
                    epochs=50,  # You can adjust epochs
                    batch_size=32,  # Batch size
                    validation_split=0.2,  # 20% of train for validation to monitor overfitting
                    verbose=1)

# Plot training history to check for overfitting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6007 - loss: 0.6620 - val_accuracy: 0.7273 - val_loss: 0.5838
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7555 - loss: 0.5576 - val_accuracy: 0.8042 - val_loss: 0.5192
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7785 - loss: 0.5193 - val_accuracy: 0.8182 - val_loss: 0.4738
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8143 - loss: 0.4649 - val_accuracy: 0.7832 - val_loss: 0.4436
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7849 - loss: 0.4829 - val_accuracy: 0.8252 - val_loss: 0.4228
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7972 - loss: 0.4614 - val_accuracy: 0.8252 - val_loss: 0.4165
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8304 - loss: 0.4445 - val_accuracy: 0.8252 - val_loss: 0.4069
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8522 - loss: 0.3955 - val_accuracy: 0.8322 - val_loss: 0.4047
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8199 - loss: 0.4239 - val_accuracy: 0.8252 - val_loss: 0.4073
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8164 - loss: 0.4199 - val_accuracy: 0.8322 - val_loss: 0.4040
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8298 - loss: 0.3980 - val_accuracy: 0.8322 - val_loss: 0.3969
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8467 - loss: 0.3698 - val_accuracy: 0.8182 - val_loss: 0.4048
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8246 - loss: 0.4053 - val_accuracy: 0.8322 - val_loss: 0.4033
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8155 - loss: 0.4265 - val_accuracy: 0.8392 - val_loss: 0.4007
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8096 - loss: 0.4076 - val_accuracy: 0.8392 - val_loss: 0.3974
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8296 - loss: 0.4162 - val_accuracy: 0.8252 - val_loss: 0.4026
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8411 - loss: 0.3918 - val_accuracy: 0.8462 - val_loss: 0.3958
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8463 - loss: 0.3764 - val_accuracy: 0.8392 - val_loss: 0.3997
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8409 - loss: 0.3826 - val_accuracy: 0.8392 - val_loss: 0.3979
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8346 - loss: 0.3807 - val_accuracy: 0.8392 - val_loss: 0.3987
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8389 - loss: 0.3864 - val_accuracy: 0.8462 - val_loss: 0.3972
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8391 - loss: 0.4129 - val_accuracy: 0.8392 - val_loss: 0.3967
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8561 - loss: 0.3498 - val_accuracy: 0.8322 - val_loss: 0.3990
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8552 - loss: 0.3539 - val_accuracy: 0.8462 - val_loss: 0.3987
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8361 - loss: 0.4038 - val_accuracy: 0.8462 - val_loss: 0.3980
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8590 - loss: 0.3551 - val_accuracy: 0.8322 - val_loss: 0.4010
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8687 - loss: 0.3462 - val_accuracy: 0.8531 - val_loss: 0.3987
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8548 - loss: 0.3645 - val_accuracy: 0.8531 - val_loss: 0.3990
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8638 - loss: 0.3496 - val_accuracy: 0.8462 - val_loss: 0.3969
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8641 - loss: 0.3541 - val_accuracy: 0.8392 - val_loss: 0.3994
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8447 - loss: 0.3919 - val_accuracy: 0.8531 - val_loss: 0.4078
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8533 - loss: 0.3389 - val_accuracy: 0.8531 - val_loss: 0.3985
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8337 - loss: 0.3700 - val_accuracy: 0.8462 - val_loss: 0.3997
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8312 - loss: 0.3941 - val_accuracy: 0.8462 - val_loss: 0.4010
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8518 - loss: 0.3517 - val_accuracy: 0.8392 - val_loss: 0.4029
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8636 - loss: 0.3354 - val_accuracy: 0.8392 - val_loss: 0.4022
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8415 - loss: 0.3613 - val_accuracy: 0.8392 - val_loss: 0.4034
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8398 - loss: 0.3594 - val_accuracy: 0.8462 - val_loss: 0.3998
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8413 - loss: 0.3523 - val_accuracy: 0.8392 - val_loss: 0.4066
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8201 - loss: 0.3760 - val_accuracy: 0.8462 - val_loss: 0.3985
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8296 - loss: 0.3573 - val_accuracy: 0.8531 - val_loss: 0.4081
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8613 - loss: 0.3283 - val_accuracy: 0.8462 - val_loss: 0.3994
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.3544 - val_accuracy: 0.8462 - val_loss: 0.4048
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8575 - loss: 0.3306 - val_accuracy: 0.8392 - val_loss: 0.4040
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8428 - loss: 0.3570 - val_accuracy: 0.8462 - val_loss: 0.4052
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8518 - loss: 0.3414 - val_accuracy: 0.8462 - val_loss: 0.4104
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8576 - loss: 0.3279 - val_accuracy: 0.8462 - val_loss: 0.4067
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8579 - loss: 0.3307 - val_accuracy: 0.8462 - val_loss: 0.4090
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8602 - loss: 0.3362 - val_accuracy: 0.8462 - val_loss: 0.4060
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8533 - loss: 0.3478 - val_accuracy: 0.8462 - val_loss: 0.4085

# %%
# Predict on test set
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Assess metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.title('Receiver Operating Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Accuracy: 0.8212
# Precision: 0.8281
# Recall: 0.7162
# F1-Score: 0.7681
